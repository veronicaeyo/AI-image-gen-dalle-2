# %%
import os
from dotenv import load_dotenv

import openai

import requests 
from PIL import Image
import matplotlib.pyplot as plt

# %%
load_dotenv()

openai.api_key = os.getenv('API_KEY')

# %% [markdown]
# ### Single Image Case

# %%
response = openai.Image.create(
  prompt="a cute bunny",
  n=1,
  size="256x256"
)

# %%
response
# Out:
# <OpenAIObject at 0x19dfcb75a30> JSON: {
#   "created": 1688597980,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-2ntky5SyvuctRiWCxo5GORoQ.png?st=2023-07-05T21%3A59%3A40Z&se=2023-07-05T23%3A59%3A40Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T20%3A14%3A13Z&ske=2023-07-06T20%3A14%3A13Z&sks=b&skv=2021-08-06&sig=xLI2tA5mXqB2lxf1Cl4UV%2Bydtwz4KMHapBnahUuoSzM%3D"
#     }
#   ]
# }

# %%
response["data"][0]["url"]
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-2ntky5SyvuctRiWCxo5GORoQ.png?st=2023-07-05T21%3A59%3A40Z&se=2023-07-05T23%3A59%3A40Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T20%3A14%3A13Z&ske=2023-07-06T20%3A14%3A13Z&sks=b&skv=2021-08-06&sig=xLI2tA5mXqB2lxf1Cl4UV%2Bydtwz4KMHapBnahUuoSzM%3D'

# %%
#open the url
url = response["data"][0]["url"]
image = Image.open(requests.get(url, stream=True).raw)
plt.imshow(image)

# %% [markdown]
# ### Multiple Images

# %%
response = openai.Image.create(
  prompt="spiderman eating a car and flying a kite",
  n=4,
  size="512x512"
)

# %%
response
# Out:
# <OpenAIObject at 0x19deafbf9b0> JSON: {
#   "created": 1688598188,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-00rnxgdjaG6cDtKrvAa8q1V7.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=ZqF2o5%2BVehj6rO/9gM3rFABFkYGzYJS7xxSHlzslFJA%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-kxTa8x8MB14FgfvmrLGWhJYE.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=FLZo69ChTiTjro2lLE0c3DSzNOafNTep0HtUB/LOcrM%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-6MvqY3Bqw3DbJcxTTQwEp1ef.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=vzYIZOTdl1Dp/l/BH7FU/S80j4t4ZsV8/pc30VZ6D9k%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-ICUHWHaJceKiKcosO8BORcbL.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=Nwu3pXTJaCCwYt22V6RKhSd%2Bl1a4P2VEN2%2BTCNu41r4%3D"
#     }
#   ]
# }

# %%
urls = [res["url"] for res in response['data']]
urls
# Out:
# ['https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-00rnxgdjaG6cDtKrvAa8q1V7.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=ZqF2o5%2BVehj6rO/9gM3rFABFkYGzYJS7xxSHlzslFJA%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-kxTa8x8MB14FgfvmrLGWhJYE.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=FLZo69ChTiTjro2lLE0c3DSzNOafNTep0HtUB/LOcrM%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-6MvqY3Bqw3DbJcxTTQwEp1ef.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=vzYIZOTdl1Dp/l/BH7FU/S80j4t4ZsV8/pc30VZ6D9k%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-ICUHWHaJceKiKcosO8BORcbL.png?st=2023-07-05T22%3A03%3A08Z&se=2023-07-06T00%3A03%3A08Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T22%3A08%3A27Z&ske=2023-07-06T22%3A08%3A27Z&sks=b&skv=2021-08-06&sig=Nwu3pXTJaCCwYt22V6RKhSd%2Bl1a4P2VEN2%2BTCNu41r4%3D']

# %%
# Images and their corresponding positions
images = [Image.open(requests.get(url, stream=True).raw) for url in urls]
positions = [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
# Loop through the images and positions to plot them in 2 subplots

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
for img, pos in zip(images, positions):
    axes[pos].imshow(img)
