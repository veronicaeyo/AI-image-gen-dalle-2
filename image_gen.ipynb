# %%
import os
from dotenv import load_dotenv

import openai

import requests 
from PIL import Image
import matplotlib.pyplot as plt

# %%
load_dotenv()

openai.api_key = os.getenv('API_KEY')

# %% [markdown]
# ### Single Image Case

# %%
response = openai.Image.create(
  prompt="a cute bunny",
  n=1,
  size="256x256"
)

# %%
response
# Out:
# <OpenAIObject at 0x19dfcb75a30> JSON: {
#   "created": 1688597980,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-2ntky5SyvuctRiWCxo5GORoQ.png?st=2023-07-05T21%3A59%3A40Z&se=2023-07-05T23%3A59%3A40Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T20%3A14%3A13Z&ske=2023-07-06T20%3A14%3A13Z&sks=b&skv=2021-08-06&sig=xLI2tA5mXqB2lxf1Cl4UV%2Bydtwz4KMHapBnahUuoSzM%3D"
#     }
#   ]
# }

# %%
response["data"][0]["url"]
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-2ntky5SyvuctRiWCxo5GORoQ.png?st=2023-07-05T21%3A59%3A40Z&se=2023-07-05T23%3A59%3A40Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-05T20%3A14%3A13Z&ske=2023-07-06T20%3A14%3A13Z&sks=b&skv=2021-08-06&sig=xLI2tA5mXqB2lxf1Cl4UV%2Bydtwz4KMHapBnahUuoSzM%3D'

# %%
#open the url
url = response["data"][0]["url"]
image = Image.open(requests.get(url, stream=True).raw)
plt.imshow(image)

# %% [markdown]
# ### Multiple Images

# %%
response = openai.Image.create(
  prompt="batman and robin flying a kite",
  n=4,
  size="512x512"
)

# %%
response
# Out:
# <OpenAIObject at 0x1abd70df710> JSON: {
#   "created": 1688674914,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-6CLb8VHm6tbDehdyWr9tPhcI.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=LwBKWuMYnshLRf8t9HRC18Xp9SP%2BKPd2WjOnQNtrcPU%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-TDjlviRsPAV6Mni4Vb0Kiwsg.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=Ag4bHypl5vNT5ezuo4CD5XinGKwgzJFC3DeRalbjjJM%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-HsavnCeXZEUEopsHCf7wZilV.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=xZjQ2cwtRRrtmbcukppWdm0iXq46/A7WmcQEpbwWSdk%3D"
#     },
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-3IoXM6fbbCOp3lqdv6hmuALF.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=qRW/N31a6hpMQOJ4O3l9wxoOyWeDlsBSJPLpQ9cYlu4%3D"
#     }
#   ]
# }

# %%
urls = [res["url"] for res in response['data']]
urls
# Out:
# ['https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-6CLb8VHm6tbDehdyWr9tPhcI.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=LwBKWuMYnshLRf8t9HRC18Xp9SP%2BKPd2WjOnQNtrcPU%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-TDjlviRsPAV6Mni4Vb0Kiwsg.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=Ag4bHypl5vNT5ezuo4CD5XinGKwgzJFC3DeRalbjjJM%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-HsavnCeXZEUEopsHCf7wZilV.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=xZjQ2cwtRRrtmbcukppWdm0iXq46/A7WmcQEpbwWSdk%3D',
#  'https://oaidalleapiprodscus.blob.core.windows.net/private/org-UODwUjyYPzLPSUgqp1SkNJpG/user-ZUQOqQbG4YNvFXMkbS4qjkf8/img-3IoXM6fbbCOp3lqdv6hmuALF.png?st=2023-07-06T19%3A21%3A54Z&se=2023-07-06T21%3A21%3A54Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-07-06T09%3A27%3A27Z&ske=2023-07-07T09%3A27%3A27Z&sks=b&skv=2021-08-06&sig=qRW/N31a6hpMQOJ4O3l9wxoOyWeDlsBSJPLpQ9cYlu4%3D']

# %%
# Images and their corresponding positions
images = [Image.open(requests.get(url, stream=True).raw) for url in urls]
positions = [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
# Loop through the images and positions to plot them in 2 subplots

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
for img, pos in zip(images, positions):
    axes[pos].imshow(img)
